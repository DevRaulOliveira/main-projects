# %%
# %py
pip install pdfplumber
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 30.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %restart_python

# %%
import pdfplumber
import glob
import os

pdf_path = "/Workspace/Users/raul_cez@outlook.com/github_databricks/pdf_reader/template/*.pdf"
pdf_files = glob.glob(pdf_path)

all_words = []

if pdf_files:
    with pdfplumber.open(pdf_files[0]) as pdf:
        page = pdf.pages[0]
        for coords in vetores:
            area = page.crop(coords, relative=False, strict=False)
            words = area.extract_words()
            all_words.extend(words)
    print("Palavras extraídas de todas as áreas:", all_words)
else:
    print("No PDF files found at the specified path.")
# Out:
# Palavras extraídas de todas as áreas: [{'text': 'Mestre', 'x0': 46.0, 'x1': 84.67599999999999, 'top': 122.48400000000004, 'doctop': 122.48400000000004, 'bottom': 122.48400000000004, 'upright': True, 'height': 0.0, 'width': 38.67599999999999, 'direction': 'ltr'}, {'text': 'TED-2025-0001', 'x0': 59.34, 'x1': 130.48000000000002, 'top': 142.07000000000005, 'doctop': 142.07000000000005, 'bottom': 142.07000000000005, 'upright': True, 'height': 0.0, 'width': 71.14000000000001, 'direction': 'ltr'}, {'text': '2025-12-13', 'x0': 71.02000000000001, 'x1': 122.16000000000003, 'top': 154.07000000000005, 'doctop': 154.07000000000005, 'bottom': 154.07000000000005, 'upright': True, 'height': 0.0, 'width': 51.140000000000015, 'direction': 'ltr'}, {'text': 'Empresa', 'x0': 82.12, 'x1': 122.13000000000001, 'top': 166.07000000000005, 'doctop': 166.07000000000005, 'bottom': 166.07000000000005, 'upright': True, 'height': 0.0, 'width': 40.010000000000005, 'direction': 'ltr'}, {'text': 'A', 'x0': 124.9100000
# ...

# %%
vetores = [
    (46.0, 122.48400000000004, 84.67599999999999, 122.48400000000004),
    (59.34, 142.07000000000005, 130.48000000000002, 142.07000000000005),
    (71.02000000000001, 154.07000000000005, 122.16000000000003, 154.07000000000005),
    (82.12, 166.07000000000005, 131.58, 166.07000000000005),
    (83.80000000000001, 178.07000000000005, 133.26, 178.07000000000005),
    (73.24000000000001, 190.07000000000005, 410.16000000000014, 190.07000000000005),
    (46.0, 222.48400000000004, 98.008, 222.48400000000004),
    (69.9, 242.07000000000005, 159.41000000000003, 242.07000000000005),
    (59.34, 254.07000000000005, 134.40000000000003, 254.07000000000005),
    (76.57000000000001, 266.07000000000005, 154.37, 266.07000000000005),
    (93.25, 278.07000000000005, 171, 278.07000000000005),
    (73.24000000000001, 290.07000000000005, 416.82000000000005, 290.07000000000005)
]

# %%
import pdfplumber
import glob
import os

pdf_path = '/Workspace/Users/raul_cez@outlook.com/github_databricks/pdf_reader/template/*.pdf'
pdf_files = glob.glob(pdf_path)

column_names = [
    'tipo', 'id', 'data', 'origem', 'destino', 'hash mestre', 'tipo',
    'cnpj', 'ie', 'nome', 'endereco', 'hash cadastro'
]
data = []

for pdf_path in pdf_files:
    with pdfplumber.open(pdf_path) as pdf:
        page = pdf.pages[0]
        row = {}
        for idx, coords in enumerate(vetores):
            area = page.crop(coords, relative=False, strict=False)
            text = area.extract_text()
            row[column_names[idx]] = text
        row['arquivo'] = os.path.basename(pdf_path)
        data.append(row)

df = spark.createDataFrame(data)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>arquivo</th><th>cnpj</th><th>data</th><th>destino</th><th>endereco</th><th>hash cadastro</th><th>hash mestre</th><th>id</th><th>ie</th><th>nome</th><th>origem</th><th>tipo</th></tr></thead><tbody><tr><td>ted_sp_sample.pdf</td><td>12.345.678/0001-99</td><td>2025-12-13</td><td>Empresa B</td><td>Av. Exemplo, 100</td><td>3fb2a4e80ec3cbb85003c4cd88c5c2dbb0429acd0d0f8566943b66dd5fa62a8b</td><td>e490f0126f81a04943ecef4b2d1ec452f102fb9f7c1a447019b1945159215cde</td><td>TED-2025-0001</td><td>123.456.789.000</td><td>Empresa A LTDA</td><td>Empresa A</td><td>Cadastro</td></tr></tbody></table></div>
